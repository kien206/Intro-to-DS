# %%
import pandas as pd
df=pd.read_csv("PhongVu.csv")
df
# Out:
#                                                   name    brand       price  \
# 0    Điện Thoại Di Động iPhone 14 Pro Max 256GB Dee...    APPLE  38990000.0
# 1    Điện thoại Samsung Galaxy A05 (4+128) (Black) ...  SAMSUNG   3090000.0
# 2    Điện thoại Samsung Galaxy A05s (4+128) (Silver...  SAMSUNG   3990000.0
# 3    Điện thoại Samsung Galaxy M34 5G (8+128) (Dark...  SAMSUNG   7990000.0
# 4    iPhone 15 Pro Max 512GB Blue Titanium (MU7F3VN/A)    APPLE  43990000.0
# ..                                                 ...      ...         ...
# 149  Điện thoại ASUS ROG Phone 6 12GB/256GB (AI2201...     ASUS  18990000.0
# 150  Bundle Điện thoại Nubia Red Magic 6s Pro + Quà...    Nubia  19990000.0
# 151  Điện thoại ASUS ROG Phone 7 Ultimate 16GB/512G...     ASUS  29990000.0
# 152  Điện thoại Samsung Galaxy A53 5G (8+128GB) (Bl...  SAMSUNG   9990000.0
# 153  Điện thoại Samsung Galaxy A53 5G (8+128GB) (Bl...  SAMSUNG   9990000.0
#
# ...
