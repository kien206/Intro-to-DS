# %%
import pandas as pd
df=pd.read_csv("processed_db.csv")
df.head(10)
# Out:
#    Unnamed: 0                                              Model  \
# 0           0               Basio active 5G TD-LTE JP 64GB SHG09
# 1           1  P60 Pro 4G Premium Edition Dual SIM TD-LTE CN ...
# 2           3  SM-A146U Galaxy A14 5G 2023 Standard Edition T...
# 3           4  Vivo Y01 2022 Premium Edition Dual SIM TD-LTE ...
# 4           5  Realme 9 Pro+ 5G 2022 Premium Edition Dual SIM...
# 5           6  Black Shark 5 Pro 5G Standard Edition Dual SIM...
# 6           7  Vivo Y12s Dual SIM TD-LTE V3 MY VN SG 128GB V2026
# 7           8  Realme C35 2022 Standard Edition Global Dual S...
# 8           9     Vivo X Flip 5G Dual SIM TD-LTE CN 512GB V2256A
# 9          10  Black Shark 5 Pro 5G Top Edition Global Dual S...
#
#    Secondary Display Type  Wireless Charging Platform Device Category  \
# 0                   False              False  Android      Smartphone
# 1                   False               True  Android      Smartphone
# ...

# %%
df["Secondary Display Type"].value_counts()
# Out:
# False    3054
# True      187
# Name: Secondary Display Type, dtype: int64

# %%
df["currency"]="USD"

# %%
df.head(7)
# Out:
#    Unnamed: 0                                              Model  \
# 0           0               Basio active 5G TD-LTE JP 64GB SHG09
# 1           1  P60 Pro 4G Premium Edition Dual SIM TD-LTE CN ...
# 2           3  SM-A146U Galaxy A14 5G 2023 Standard Edition T...
# 3           4  Vivo Y01 2022 Premium Edition Dual SIM TD-LTE ...
# 4           5  Realme 9 Pro+ 5G 2022 Premium Edition Dual SIM...
# 5           6  Black Shark 5 Pro 5G Standard Edition Dual SIM...
# 6           7  Vivo Y12s Dual SIM TD-LTE V3 MY VN SG 128GB V2026
#
#    Secondary Display Type  Wireless Charging Platform Device Category  \
# 0                   False              False  Android      Smartphone
# 1                   False               True  Android      Smartphone
# 2                   False              False  Android      Smartphone
# 3                   False              False  Android      Smartphone
# 4                   False              False  Android      Smartphone
# ...

# %%
df.dropna(subset=["Price"],inplace=True)

# %%
df.to_csv("final1.csv", index=False)
